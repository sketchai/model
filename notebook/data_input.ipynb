# %% [markdown]
# # Analyse des entrées du modèle

# %%
import logging
logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

# %%
import sys 
SG_PATH = '/home/i37181/Documents/Projets/CAO/SketchGraphs/sketchgraphs'
sys.path.append(SG_PATH)

# %% [markdown]
# Un exemple complet a été sauvegardé dans le dossier 'tests/asset/dataset/mini_example'. Ce dossier contient en particulier :
# - 'sg_t16_mini.npy' : un fichier contenant 5 séquences sketchgraphs.

# %% [markdown]
# ## Step 1: Load the original sequence dataset
#
# Charge les 5 séquences et les affiches

# %%
PREPROCESSING_PATH = '/home/i37181/Documents/Projets/CAO/SketchGraphs/preprocessing/sketch_gnn/utils'
sys.path.append(PREPROCESSING_PATH)

from flat_array import load_flat_array, load_dictionary_flat

# %%
file_path = '/home/i37181/Documents/Projets/CAO/SketchGraphs/modelrnn_gat/tests/asset/dataset/mini_example/sg_t16_mini.npy'

try:
    print('Load dictionary flat array method')
    data = load_dictionary_flat(file_path)['sequences']
except BaseException:
    logger.info('Load flat array method')
    data = load_flat_array(file_path)
# Out:
# INFO:root:Load flat array method
# Load dictionary flat array method

# %%
from sketchgraphs.data import sketch_from_sequence
from sketchgraphs.data._plotting import render_sketch
for cpt,seq in enumerate(data) :
    print(cpt)
    render_sketch(sketch_from_sequence(seq))
# Out:
# DEBUG:matplotlib:matplotlib data path: /home/i37181/anaconda3/envs/env_gat/lib/python3.9/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:CONFIGDIR=/home/i37181/.config/matplotlib
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# ...

# %% [markdown]
# ## Step 2: Load the preprocessed sequence dataset

# %% [markdown]
# Après l'étape de préprocessing (fait avec le code d'Odilon), seulement deux sketches ont été retenus :
# - deux cercles de même centre et de rayon différents (après renormalisation, r1 = 1, r2 = 0.89)
# - le triangle (3 lignes)

# %%
MODEL_PATH = '/home/i37181/Documents/Projets/CAO/SketchGraphs/modelrnn_gat'
sys.path.append(MODEL_PATH)

# %%
from sketch_gnn.dataloader.graph_data import GraphDataset
path_seq = '/home/i37181/Documents/Projets/CAO/SketchGraphs/modelrnn_gat/tests/asset/dataset/mini_example/mini_final.npy'
path_weight = '/home/i37181/Documents/Projets/CAO/SketchGraphs/modelrnn_gat/tests/asset/dataset/mini_example/mini_weights.npy'
graph_dataset = GraphDataset(path_seq=path_seq, path_weights=path_weight, n_slice=None)

# %%
len(graph_dataset)

# %%
# Sketch A : deux cercles partageant le même centre
graph_dataset[0].get('node_ops')[:10]

# %%
# Sketch B : le triangle
graph_dataset[1].get('node_ops')[:15]

# %%
# Get all keys
graph_dataset[1].keys()

# %%
graph_dataset[1].get('mask_attention')

# %% [markdown]
# En détails : le triangle

# %%
graph_dataset[1].get()

# %%
import matplotlib.pyplot as plt
for i,seq in enumerate(data) :
    if i ==4:
        fig = render_sketch(sketch_from_sequence(seq))
        plt.savefig('triangle.png', format="png")

# %% [markdown]
# ## Step 3: Prepare data for the NN

# %%
from sketch_gnn.dataloader.collate import collate

# %% [markdown]
# Pour passer des données encodées enregistrées dans 'mini_final.npy' au format chargé dans le dataloader, une étape de reconstruction est nécessaire. Celle-ci a lieu au niveau de la fonction collate ('sketch_gnn/dataloader/collate.py).
#
# Cette fonction a pour but de créer des batchs, mais pas seulement. L'étape de construction des features *edges_toInf_pos* et *edges_toInf_pos_types* ont lieu ici.

# %%
batch = collate(graph_dataset, 
                node_feature_dims=, 
                edge_feature_dims, 
                lMax=)
